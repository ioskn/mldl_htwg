# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import tree
plt.figure(figsize=(6,6))
plt.style.use('default') # macht den hintergrund weg 
plt.rcParams.update({'font.size': 15}) #Macht grosse axen

# %%
xs = np.linspace(-2,2,100)
plt.plot(xs, np.exp(-xs))
plt.plot(xs,np.log(1 + np.exp(-2*xs)) + np.log(2)) #Constant offset
plt.legend(['Exponential', 'Logistic'])
plt.ylabel('loss')
plt.xlabel('yf')
# Out:
# Text(0.5, 0, 'yf')
